# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics
import os
plt.ion()

# %%
cases= pd.read_csv('C:/Users/limwe/OneDrive/Desktop/School/Year 2/Programming/Sub Problem 1/data_table_for_weekly_case_trends__the_united_states.csv', skiprows = 2)
cases #number of cases on a weekly basis
# Out:
#              State         Date  Weekly Cases  Historic Cases
# 0    United States  Oct 19 2022        260808               0
# 1    United States  Oct 12 2022        265175               0
# 2    United States  Oct  5 2022        309887               0
# 3    United States  Sep 28 2022        342162               0
# 4    United States  Sep 21 2022        395071               0
# ..             ...          ...           ...             ...
# 138  United States  Feb 26 2020            31               0
# 139  United States  Feb 19 2020            16               0
# 140  United States  Feb 12 2020            10               0
# 141  United States  Feb  5 2020            10               0
# 142  United States  Jan 29 2020             7               0
#
# [143 rows x 4 columns]

# %%
casescleaned = cases.drop(labels=range(28, 143), axis=0) #remove data for the period from 29/1/2020 to 6/4/2022
casescleaned
# Out:
#             State         Date  Weekly Cases  Historic Cases
# 0   United States  Oct 19 2022        260808               0
# 1   United States  Oct 12 2022        265175               0
# 2   United States  Oct  5 2022        309887               0
# 3   United States  Sep 28 2022        342162               0
# 4   United States  Sep 21 2022        395071               0
# 5   United States  Sep 14 2022        471611               0
# 6   United States  Sep  7 2022        525650               0
# 7   United States  Aug 31 2022        616637               0
# 8   United States  Aug 24 2022        651675               0
# 9   United States  Aug 17 2022        694190               0
# 10  United States  Aug 10 2022        772447               0
# 11  United States  Aug  3 2022        839467               0
# 12  United States  Jul 27 2022        924235               0
# 13  United States  Jul 20 2022        905366               0
# ...

# %%
casescleanedremoveindex0 = casescleaned.drop(labels=0, axis=0) #remove the data for 19/10/2022
casescleanedremoveindex0
# Out:
#             State         Date  Weekly Cases  Historic Cases
# 1   United States  Oct 12 2022        265175               0
# 2   United States  Oct  5 2022        309887               0
# 3   United States  Sep 28 2022        342162               0
# 4   United States  Sep 21 2022        395071               0
# 5   United States  Sep 14 2022        471611               0
# 6   United States  Sep  7 2022        525650               0
# 7   United States  Aug 31 2022        616637               0
# 8   United States  Aug 24 2022        651675               0
# 9   United States  Aug 17 2022        694190               0
# 10  United States  Aug 10 2022        772447               0
# 11  United States  Aug  3 2022        839467               0
# 12  United States  Jul 27 2022        924235               0
# 13  United States  Jul 20 2022        905366               0
# 14  United States  Jul 13 2022        865597               0
# ...

# %%
casesnumber = pd.DataFrame(casescleanedremoveindex0['Weekly Cases']) #extracting numeric data
casesnumber
# Out:
#     Weekly Cases
# 1         265175
# 2         309887
# 3         342162
# 4         395071
# 5         471611
# 6         525650
# 7         616637
# 8         651675
# 9         694190
# 10        772447
# 11        839467
# 12        924235
# 13        905366
# 14        865597
# 15        779723
# 16        771796
# 17        693800
# 18        725592
# 19        771661
# 20        715689
# 21        771946
# 22        696358
# 23        588378
# 24        450185
# 25        367353
# 26        291769
# 27        226512

# %%
casesnumber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 1 to 27
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weekly Cases  27 non-null     int64
# dtypes: int64(1)
# memory usage: 348.0 bytes

# %%
casesnumber.describe() #statistical summary
# Out:
#         Weekly Cases
# count      27.000000
# mean   608516.000000
# std    212305.530321
# min    226512.000000
# 25%    422628.000000
# 50%    693800.000000
# 75%    771871.000000
# max    924235.000000

# %%
f, axes = plt.subplots(3, 1, figsize=(24, 30))

sb.boxplot(data = casesnumber, orient = "h", ax = axes[0])
sb.histplot(data = casesnumber, kde = True, ax = axes[1])
sb.violinplot(data = casesnumber, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
death= pd.read_csv('C:/Users/limwe/OneDrive/Desktop/School/Year 2/Programming/Sub Problem 1/data_table_for_weekly_death_trends__the_united_states.csv', skiprows = 2)
death #number of death on a weekly basis
# Out:
#              State         Date  Weekly Deaths  Historic Deaths
# 0    United States  Oct 19 2022           2566                0
# 1    United States  Oct 12 2022           2582                0
# 2    United States  Oct  5 2022           2994                0
# 3    United States  Sep 28 2022           2974              469
# 4    United States  Sep 21 2022           3158                0
# ..             ...          ...            ...              ...
# 138  United States  Feb 26 2020              0                0
# 139  United States  Feb 19 2020              0                0
# 140  United States  Feb 12 2020              0                0
# 141  United States  Feb  5 2020              0                0
# 142  United States  Jan 29 2020              0                0
#
# [143 rows x 4 columns]

# %%
deathcleaned = death.drop(labels=range(28, 143), axis=0) #remove data for the period from 29/1/2020 to 6/4/2022
deathcleaned
# Out:
#             State         Date  Weekly Deaths  Historic Deaths
# 0   United States  Oct 19 2022           2566                0
# 1   United States  Oct 12 2022           2582                0
# 2   United States  Oct  5 2022           2994                0
# 3   United States  Sep 28 2022           2974              469
# 4   United States  Sep 21 2022           3158                0
# 5   United States  Sep 14 2022           3230                0
# 6   United States  Sep  7 2022           2972                0
# 7   United States  Aug 31 2022           4052                0
# 8   United States  Aug 24 2022           3247                0
# 9   United States  Aug 17 2022           3041                0
# 10  United States  Aug 10 2022           3934                0
# 11  United States  Aug  3 2022           3554                0
# 12  United States  Jul 27 2022           3170                0
# 13  United States  Jul 20 2022           2813                0
# ...

# %%
deathcleanedremoveindex0 = deathcleaned.drop(labels=0, axis=0) #remove the data for 19/10/2022
deathcleanedremoveindex0
# Out:
#             State         Date  Weekly Deaths  Historic Deaths
# 1   United States  Oct 12 2022           2582                0
# 2   United States  Oct  5 2022           2994                0
# 3   United States  Sep 28 2022           2974              469
# 4   United States  Sep 21 2022           3158                0
# 5   United States  Sep 14 2022           3230                0
# 6   United States  Sep  7 2022           2972                0
# 7   United States  Aug 31 2022           4052                0
# 8   United States  Aug 24 2022           3247                0
# 9   United States  Aug 17 2022           3041                0
# 10  United States  Aug 10 2022           3934                0
# 11  United States  Aug  3 2022           3554                0
# 12  United States  Jul 27 2022           3170                0
# 13  United States  Jul 20 2022           2813                0
# 14  United States  Jul 13 2022           3443                0
# ...

# %%
deathnumber = pd.DataFrame(deathcleanedremoveindex0['Weekly Deaths']) #extracting numeric data
deathnumber
# Out:
#     Weekly Deaths
# 1            2582
# 2            2994
# 3            2974
# 4            3158
# 5            3230
# 6            2972
# 7            4052
# 8            3247
# 9            3041
# 10           3934
# 11           3554
# 12           3170
# 13           2813
# 14           3443
# 15           1700
# 16           2557
# 17           2029
# 18           2173
# 19           2346
# 20           2127
# 21           2659
# 22           4154
# 23           2335
# 24           2805
# 25           2970
# 26           3047
# 27           3859

# %%
deathnumber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 1 to 27
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Weekly Deaths  27 non-null     int64
# dtypes: int64(1)
# memory usage: 348.0 bytes

# %%
deathnumber.describe()
# Out:
#        Weekly Deaths
# count      27.000000
# mean     2960.185185
# std       626.104196
# min      1700.000000
# 25%      2569.500000
# 50%      2974.000000
# 75%      3238.500000
# max      4154.000000

# %%
f, axes = plt.subplots(3, 1, figsize=(24, 30))

sb.boxplot(data = deathnumber, orient = "h", ax = axes[0])
sb.histplot(data = deathnumber, kde = True, ax = axes[1])
sb.violinplot(data = deathnumber, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
hospitalisation=pd.read_csv('C:/Users/limwe/OneDrive/Desktop/School/Year 2/Programming/Sub Problem 1/United_States_COVID-19.csv', skiprows = 0)
hospitalisation #number of hospitalisation admissions on a weekly basis
# Out:
#     county_fips  county_population  health_service_area_number  \
# 0     101360409          331816009                     1291263
# 1     101360409          331816009                     1291263
# 2     101360409          331816009                     1291263
# 3     101360409          331816009                     1291263
# 4     101360409          331816009                     1291263
# 5     101360409          331816009                     1291263
# 6     101360409          331816009                     1291263
# 7     101360409          331816009                     1291263
# 8     101360409          331816009                     1291263
# 9     101360409          331816009                     1291263
# 10    101360409          331816009                     1291263
# 11    101360409          331816009                     1291263
# 12    101360409          331816009                     1291263
# 13    101360409          331816009                     1291263
# ...

# %%
hospitalisationcleaned=pd.DataFrame(hospitalisation['covid_hospital_admissions_per_100k']) #extracting numeric data
hospitalisationcleaned
# Out:
#     covid_hospital_admissions_per_100k
# 0                              20290.7
# 1                              21751.3
# 2                              23674.8
# 3                              27126.6
# 4                              29579.8
# 5                              31236.2
# 6                              34949.7
# 7                              36289.7
# 8                              38227.8
# 9                              41256.9
# 10                             41380.9
# 11                             41707.3
# 12                             39586.4
# 13                             37065.3
# 14                             31381.8
# 15                             29202.6
# 16                             26494.8
# 17                             24794.0
# 18                             23425.1
# 19                             20556.1
# 20                             18810.2
# 21                             16476.4
# 22                             13053.5
# ...

# %%
hospitalisationcleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 1 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(1)
# memory usage: 344.0 bytes

# %%
hospitalisationcleaned.describe()
# Out:
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
f, axes = plt.subplots(3, 1, figsize=(24, 30))

sb.boxplot(data = hospitalisationcleaned, orient = "h", ax = axes[0])
sb.histplot(data = hospitalisationcleaned, kde = True, ax = axes[1])
sb.violinplot(data = hospitalisationcleaned, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
vaccine = pd.read_csv('C:/Users/limwe/OneDrive/Desktop/School/Year 2/Programming/Sub Problem 1/COVID-19_Vaccinations_in_the_United_States.csv', skiprows = 0)
vaccine #vaccine details
# Out:
#           Date  MMWR_week  Distributed  Distributed_Janssen  \
# 0   10/12/2022         41   1762964020             63590100
# 1    10/5/2022         40   1745572140             63554200
# 2   09/28/2022         39   1727110240             63505400
# 3   09/21/2022         38   1706120340             63457400
# 4   09/14/2022         37   1687434140             63400500
# 5     9/7/2022         36   1653452640             63347300
# 6   08/31/2022         35   1638208920             63303500
# 7   08/24/2022         34   1631958420             63272400
# 8   08/17/2022         33   1624747620             63213900
# 9    8/10/2022         32   1617077920             63184800
# 10    8/3/2022         31   1606563620             63109300
# 11  07/27/2022         30   1597453780             63066200
# 12  07/20/2022         29   1586189420             62998600
# 13  07/13/2022         28   1577051320             62954300
# 14    7/6/2022         27   1566460760             62884100
# ...

# %%
vaccinecleaned=pd.DataFrame(vaccine[['Date', 'Administered_5Plus', 'Administered_12Plus', 'Administered_18Plus', 'Administered_65Plus']]) 
vaccinecleaned #extracting the data for different age group
# Out:
#           Date  Administered_5Plus  Administered_12Plus  Administered_18Plus  \
# 0   10/12/2022          1266004514           1222224912           1144729106
# 1    10/5/2022          1258809948           1215144671           1137854489
# 2   09/28/2022          1250096515           1206591264           1129564284
# 3   09/21/2022          1243103862           1199748605           1122919064
# 4   09/14/2022          1236575592           1193415924           1116793302
# 5     9/7/2022          1232650788           1189690687           1113213942
# 6   08/31/2022          1231507766           1188745055           1112370207
# 7   08/24/2022          1229606422           1187139234           1110924014
# 8   08/17/2022          1227206656           1185092258           1109075022
# 9    8/10/2022          1224668561           1182930035           1107124957
# 10    8/3/2022          1221194741           1179843023           1104273090
# ...

# %%
vaccinecleaned5years=pd.DataFrame(vaccinecleaned['Administered_5Plus']) #extracting the data for each age group
vaccinecleaned12years=pd.DataFrame(vaccinecleaned['Administered_12Plus'])
vaccinecleaned18years=pd.DataFrame(vaccinecleaned['Administered_18Plus'])
vaccinecleaned65years=pd.DataFrame(vaccinecleaned['Administered_65Plus'])
vaccinecleaned5years
# Out:
#     Administered_5Plus
# 0           1266004514
# 1           1258809948
# 2           1250096515
# 3           1243103862
# 4           1236575592
# 5           1232650788
# 6           1231507766
# 7           1229606422
# 8           1227206656
# 9           1224668561
# 10          1221194741
# 11          1220478809
# 12          1216470946
# 13          1212381972
# 14          1209324048
# 15          1206745026
# 16          1202617999
# 17          1199098183
# 18          1194822855
# 19          1190738501
# 20          1185906244
# 21          1180556821
# 22          1175080970
# 23          1169582630
# 24          1163395319
# 25          1155852259
# 26          1149215349

# %%
combined = pd.concat([vaccinecleaned5years, casesnumber], axis = 1).reindex(vaccinecleaned5years.index) 
sb.jointplot(data = combined, x = "Administered_5Plus", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 5 to 11 vs case number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned12years, casesnumber], axis = 1).reindex(vaccinecleaned12years.index) 
sb.jointplot(data = combined, x = "Administered_12Plus", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 12 to 17 vs case number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned18years, casesnumber], axis = 1).reindex(vaccinecleaned18years.index) 
sb.jointplot(data = combined, x = "Administered_18Plus", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 18 to 64 vs case number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned65years, casesnumber], axis = 1).reindex(vaccinecleaned65years.index) 
sb.jointplot(data = combined, x = "Administered_65Plus", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 65 or above vs case number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned5years, deathnumber], axis = 1).reindex(vaccinecleaned5years.index) 
sb.jointplot(data = combined, x = "Administered_5Plus", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 5 to 11 vs death number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned12years, deathnumber], axis = 1).reindex(vaccinecleaned12years.index) 
sb.jointplot(data = combined, x = "Administered_12Plus", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 12 to 17 vs death number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned18years, deathnumber], axis = 1).reindex(vaccinecleaned18years.index) 
sb.jointplot(data = combined, x = "Administered_18Plus", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 18 to 64 vs death number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned65years, deathnumber], axis = 1).reindex(vaccinecleaned65years.index) 
sb.jointplot(data = combined, x = "Administered_65Plus", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 65 or above vs death number
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned5years, hospitalisationcleaned], axis = 1).reindex(vaccinecleaned5years.index) 
sb.jointplot(data = combined, x = "Administered_5Plus", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 5 to 11 vs hospitalisation
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned12years, hospitalisationcleaned], axis = 1).reindex(vaccinecleaned12years.index) 
sb.jointplot(data = combined, x = "Administered_12Plus", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 12 to 17 vs hospitalisation
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned18years, hospitalisationcleaned], axis = 1).reindex(vaccinecleaned18years.index) 
sb.jointplot(data = combined, x = "Administered_18Plus", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 18 to 64 above vs hospitalisation
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([vaccinecleaned65years, hospitalisationcleaned], axis = 1).reindex(vaccinecleaned65years.index) 
sb.jointplot(data = combined, x = "Administered_65Plus", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #Age 65 or above vs hospitalisation
# Out:
# <AxesSubplot:>

# %%
vaccinetype=pd.DataFrame(vaccine[['Date', 'Administered_Janssen', 'Administered_Moderna', 'Administered_Pfizer', 'Administered_Novavax']])
vaccinetype #type of vaccine
# Out:
#           Date  Administered_Janssen  Administered_Moderna  \
# 0   10/12/2022              38231027             478320828
# 1    10/5/2022              38222094             475682213
# 2   09/28/2022              38204327             472658942
# 3   09/21/2022              38190149             470313002
# 4   09/14/2022              38174475             468109661
# 5     9/7/2022              38161040             466327117
# 6   08/31/2022              38147982             465887930
# 7   08/24/2022              38130397             465179986
# 8   08/17/2022              38109603             464279586
# 9    8/10/2022              38087745             463325081
# 10    8/3/2022              38062212             461901372
# 11  07/27/2022              38132505             461553903
# 12  07/20/2022              38107592             459871600
# 13  07/13/2022              38080888             458247889
# 14    7/6/2022              38062240             457090415
# ...

# %%
janssen=pd.DataFrame(vaccine['Administered_Janssen'])
moderna=pd.DataFrame(vaccine['Administered_Moderna'])
pfizer=pd.DataFrame(vaccine['Administered_Pfizer'])
novavax=pd.DataFrame(vaccine['Administered_Novavax'])
moderna
# Out:
#     Administered_Moderna
# 0              478320828
# 1              475682213
# 2              472658942
# 3              470313002
# 4              468109661
# 5              466327117
# 6              465887930
# 7              465179986
# 8              464279586
# 9              463325081
# 10             461901372
# 11             461553903
# 12             459871600
# 13             458247889
# 14             457090415
# 15             456083999
# 16             454616723
# 17             453345061
# 18             451725742
# 19             450192843
# 20             448324478
# 21             446144226
# 22             443758890
# 23             441552713
# 24             438929948
# 25             435637043
# 26             432833036

# %%
combined = pd.concat([janssen, casesnumber], axis = 1).reindex(janssen.index)
sb.jointplot(data = combined, x = "Administered_Janssen", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #janssen vs casenumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([moderna, casesnumber], axis = 1).reindex(moderna.index)
sb.jointplot(data = combined, x = "Administered_Moderna", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #moderna vs casenumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([pfizer, casesnumber], axis = 1).reindex(pfizer.index)
sb.jointplot(data = combined, x = "Administered_Pfizer", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #pfizer vs casenumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([novavax, casesnumber], axis = 1).reindex(novavax.index)
sb.jointplot(data = combined, x = "Administered_Novavax", y = "Weekly Cases", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #novavax vs casenumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([janssen, deathnumber], axis = 1).reindex(janssen.index)
sb.jointplot(data = combined, x = "Administered_Janssen", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #janssen vs deathnumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([moderna, deathnumber], axis = 1).reindex(moderna.index)
sb.jointplot(data = combined, x = "Administered_Moderna", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #moderna vs deathnumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([pfizer, deathnumber], axis = 1).reindex(pfizer.index)
sb.jointplot(data = combined, x = "Administered_Pfizer", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #pfizer vs deathnumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([novavax, deathnumber], axis = 1).reindex(novavax.index)
sb.jointplot(data = combined, x = "Administered_Novavax", y = "Weekly Deaths", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #novavax vs deathnumber
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([janssen, hospitalisationcleaned], axis = 1).reindex(janssen.index)
sb.jointplot(data = combined, x = "Administered_Janssen", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #janssen vs hospitaladmissions
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([moderna, hospitalisationcleaned], axis = 1).reindex(moderna.index)
sb.jointplot(data = combined, x = "Administered_Moderna", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #moderna vs hospitaladmissions
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([pfizer, hospitalisationcleaned], axis = 1).reindex(pfizer.index)
sb.jointplot(data = combined, x = "Administered_Pfizer", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #pfizer vs hospitaladmissions
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([novavax, hospitalisationcleaned], axis = 1).reindex(novavax.index)
sb.jointplot(data = combined, x = "Administered_Novavax", y = "covid_hospital_admissions_per_100k", height = 12)
f = plt.figure(figsize=(12, 8))
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f") #novavax vs hospitaladmissions
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Multi - Variate Relation

# %%
fiveyears=pd.DataFrame(vaccinecleaned['Administered_5Plus']) #Age 5 to 11
twelveyears=pd.DataFrame(vaccinecleaned['Administered_12Plus']) #Age 12 to 17
eighteenyears=pd.DataFrame(vaccinecleaned['Administered_18Plus']) #Age 18 to 64
sixtyfiveyears=pd.DataFrame(vaccinecleaned['Administered_65Plus']) #Age 65 or above
fiveyears
# Out:
#     Administered_5Plus
# 0           1266004514
# 1           1258809948
# 2           1250096515
# 3           1243103862
# 4           1236575592
# 5           1232650788
# 6           1231507766
# 7           1229606422
# 8           1227206656
# 9           1224668561
# 10          1221194741
# 11          1220478809
# 12          1216470946
# 13          1212381972
# 14          1209324048
# 15          1206745026
# 16          1202617999
# 17          1199098183
# 18          1194822855
# 19          1190738501
# 20          1185906244
# 21          1180556821
# 22          1175080970
# 23          1169582630
# 24          1163395319
# 25          1155852259
# 26          1149215349

# %%
fiveyears['Weekly Cases']=casesnumber
fiveyears #add weekly cases
# Out:
#     Administered_5Plus  Weekly Cases
# 0           1266004514           NaN
# 1           1258809948      265175.0
# 2           1250096515      309887.0
# 3           1243103862      342162.0
# 4           1236575592      395071.0
# 5           1232650788      471611.0
# 6           1231507766      525650.0
# 7           1229606422      616637.0
# 8           1227206656      651675.0
# 9           1224668561      694190.0
# 10          1221194741      772447.0
# 11          1220478809      839467.0
# 12          1216470946      924235.0
# 13          1212381972      905366.0
# 14          1209324048      865597.0
# 15          1206745026      779723.0
# 16          1202617999      771796.0
# 17          1199098183      693800.0
# 18          1194822855      725592.0
# 19          1190738501      771661.0
# 20          1185906244      715689.0
# 21          1180556821      771946.0
# 22          1175080970      696358.0
# 23          1169582630      588378.0
# ...

# %%
fiveyears['Weekly Deaths']=deathnumber #add weekly deaths

# %%
fiveyears['covid_hospital_admissions_per_100k']=hospitalisationcleaned
fiveyears #add hospital admissions
# Out:
#     Administered_5Plus  Weekly Cases  Weekly Deaths  \
# 0           1266004514           NaN            NaN
# 1           1258809948      265175.0         2582.0
# 2           1250096515      309887.0         2994.0
# 3           1243103862      342162.0         2974.0
# 4           1236575592      395071.0         3158.0
# 5           1232650788      471611.0         3230.0
# 6           1231507766      525650.0         2972.0
# 7           1229606422      616637.0         4052.0
# 8           1227206656      651675.0         3247.0
# 9           1224668561      694190.0         3041.0
# 10          1221194741      772447.0         3934.0
# 11          1220478809      839467.0         3554.0
# 12          1216470946      924235.0         3170.0
# 13          1212381972      905366.0         2813.0
# 14          1209324048      865597.0         3443.0
# 15          1206745026      779723.0         1700.0
# 16          1202617999      771796.0         2557.0
# ...

# %%
fiveyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_5Plus                  27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
# Summary Statistics for all Variables
fiveyears.describe()
# Out:
#        Administered_5Plus   Weekly Cases  Weekly Deaths  \
# count        2.700000e+01      26.000000      26.000000
# mean         1.209396e+09  623208.461538    2925.615385
# std          3.098244e+07  202027.221753     611.660957
# min          1.149215e+09  265175.000000    1700.000000
# 25%          1.188322e+09  455541.500000    2563.250000
# 50%          1.212382e+09  693995.000000    2973.000000
# 75%          1.230557e+09  771908.500000    3215.000000
# max          1.266005e+09  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in fiveyears:
    sb.boxplot(data = fiveyears[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = fiveyears[var], kde = True, ax = axes[count,1])
    sb.violinplot(data = fiveyears[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(fiveyears.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = fiveyears)

# %%
twelveyears['Weekly Cases']=casesnumber # add weekly cases

# %%
twelveyears
# Out:
#     Administered_12Plus  Weekly Cases
# 0            1222224912           NaN
# 1            1215144671      265175.0
# 2            1206591264      309887.0
# 3            1199748605      342162.0
# 4            1193415924      395071.0
# 5            1189690687      471611.0
# 6            1188745055      525650.0
# 7            1187139234      616637.0
# 8            1185092258      651675.0
# 9            1182930035      694190.0
# 10           1179843023      772447.0
# 11           1179392624      839467.0
# 12           1175753787      924235.0
# 13           1172038104      905366.0
# 14           1169298417      865597.0
# 15           1166992719      779723.0
# 16           1163292091      771796.0
# 17           1160117680      693800.0
# 18           1156292399      725592.0
# 19           1152627729      771661.0
# 20           1148198704      715689.0
# 21           1143122064      771946.0
# 22           1137768701      696358.0
# 23           1132446213      588378.0
# ...

# %%
twelveyears['Weekly Deaths']=deathnumber #add weekly deaths

# %%
twelveyears['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
twelveyears
# Out:
#     Administered_12Plus  Weekly Cases  Weekly Deaths  \
# 0            1222224912           NaN            NaN
# 1            1215144671      265175.0         2582.0
# 2            1206591264      309887.0         2994.0
# 3            1199748605      342162.0         2974.0
# 4            1193415924      395071.0         3158.0
# 5            1189690687      471611.0         3230.0
# 6            1188745055      525650.0         2972.0
# 7            1187139234      616637.0         4052.0
# 8            1185092258      651675.0         3247.0
# 9            1182930035      694190.0         3041.0
# 10           1179843023      772447.0         3934.0
# 11           1179392624      839467.0         3554.0
# 12           1175753787      924235.0         3170.0
# 13           1172038104      905366.0         2813.0
# 14           1169298417      865597.0         3443.0
# 15           1166992719      779723.0         1700.0
# 16           1163292091      771796.0         2557.0
# ...

# %%
twelveyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_12Plus                 27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
twelveyears.describe()
# Out:
#        Administered_12Plus   Weekly Cases  Weekly Deaths  \
# count         2.700000e+01      26.000000      26.000000
# mean          1.169119e+09  623208.461538    2925.615385
# std           2.856941e+07  202027.221753     611.660957
# min           1.112702e+09  265175.000000    1700.000000
# 25%           1.150413e+09  455541.500000    2563.250000
# 50%           1.172038e+09  693995.000000    2973.000000
# 75%           1.187942e+09  771908.500000    3215.000000
# max           1.222225e+09  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in twelveyears:
    sb.boxplot(data = twelveyears[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = twelveyears[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = twelveyears[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(twelveyears.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = twelveyears)

# %%
eighteenyears['Weekly Cases']=casesnumber #add weekly cases

# %%
eighteenyears
# Out:
#     Administered_18Plus  Weekly Cases
# 0            1144729106           NaN
# 1            1137854489      265175.0
# 2            1129564284      309887.0
# 3            1122919064      342162.0
# 4            1116793302      395071.0
# 5            1113213942      471611.0
# 6            1112370207      525650.0
# 7            1110924014      616637.0
# 8            1109075022      651675.0
# 9            1107124957      694190.0
# 10           1104273090      772447.0
# 11           1103808363      839467.0
# 12           1100391854      924235.0
# 13           1096902129      905366.0
# 14           1094367533      865597.0
# 15           1092242526      779723.0
# 16           1088752760      771796.0
# 17           1085784445      693800.0
# 18           1082192854      725592.0
# 19           1078743235      771661.0
# 20           1074526626      715689.0
# 21           1069706599      771946.0
# 22           1064517790      696358.0
# 23           1059423798      588378.0
# ...

# %%
eighteenyears['Weekly Deaths']=deathnumber #add weekly deaths

# %%
eighteenyears['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
eighteenyears
# Out:
#     Administered_18Plus  Weekly Cases  Weekly Deaths  \
# 0            1144729106           NaN            NaN
# 1            1137854489      265175.0         2582.0
# 2            1129564284      309887.0         2994.0
# 3            1122919064      342162.0         2974.0
# 4            1116793302      395071.0         3158.0
# 5            1113213942      471611.0         3230.0
# 6            1112370207      525650.0         2972.0
# 7            1110924014      616637.0         4052.0
# 8            1109075022      651675.0         3247.0
# 9            1107124957      694190.0         3041.0
# 10           1104273090      772447.0         3934.0
# 11           1103808363      839467.0         3554.0
# 12           1100391854      924235.0         3170.0
# 13           1096902129      905366.0         2813.0
# 14           1094367533      865597.0         3443.0
# 15           1092242526      779723.0         1700.0
# 16           1088752760      771796.0         2557.0
# ...

# %%
eighteenyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_18Plus                 27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
eighteenyears.describe()
# Out:
#        Administered_18Plus   Weekly Cases  Weekly Deaths  \
# count         2.700000e+01      26.000000      26.000000
# mean          1.094098e+09  623208.461538    2925.615385
# std           2.705632e+07  202027.221753     611.660957
# min           1.040301e+09  265175.000000    1700.000000
# 25%           1.076635e+09  455541.500000    2563.250000
# 50%           1.096902e+09  693995.000000    2973.000000
# 75%           1.111647e+09  771908.500000    3215.000000
# max           1.144729e+09  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in eighteenyears:
    sb.boxplot(data = eighteenyears[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = eighteenyears[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = eighteenyears[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(eighteenyears.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = eighteenyears)

# %%
sixtyfiveyears["Weekly Cases"]=casesnumber #add weekly cases

# %%
sixtyfiveyears
# Out:
#     Administered_65Plus  Weekly Cases
# 0             337610394           NaN
# 1             334195567      265175.0
# 2             330112603      309887.0
# 3             326849308      342162.0
# 4             323958727      395071.0
# 5             322440035      471611.0
# 6             322161375      525650.0
# 7             321654473      616637.0
# 8             320977452      651675.0
# 9             320243346      694190.0
# 10            319331978      772447.0
# 11            319112793      839467.0
# 12            317598983      924235.0
# 13            316110577      905366.0
# 14            315119873      865597.0
# 15            314276307      779723.0
# 16            312921783      771796.0
# 17            311620102      693800.0
# 18            310004945      725592.0
# 19            308320553      771661.0
# 20            306294856      715689.0
# 21            303794597      771946.0
# 22            301110849      696358.0
# 23            298386322      588378.0
# ...

# %%
sixtyfiveyears['Weekly Deaths']=deathnumber #add weekly deaths

# %%
sixtyfiveyears['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
sixtyfiveyears
# Out:
#     Administered_65Plus  Weekly Cases  Weekly Deaths  \
# 0             337610394           NaN            NaN
# 1             334195567      265175.0         2582.0
# 2             330112603      309887.0         2994.0
# 3             326849308      342162.0         2974.0
# 4             323958727      395071.0         3158.0
# 5             322440035      471611.0         3230.0
# 6             322161375      525650.0         2972.0
# 7             321654473      616637.0         4052.0
# 8             320977452      651675.0         3247.0
# 9             320243346      694190.0         3041.0
# 10            319331978      772447.0         3934.0
# 11            319112793      839467.0         3554.0
# 12            317598983      924235.0         3170.0
# 13            316110577      905366.0         2813.0
# 14            315119873      865597.0         3443.0
# 15            314276307      779723.0         1700.0
# 16            312921783      771796.0         2557.0
# ...

# %%
sixtyfiveyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_65Plus                 27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
sixtyfiveyears.describe()
# Out:
#        Administered_65Plus   Weekly Cases  Weekly Deaths  \
# count         2.700000e+01      26.000000      26.000000
# mean          3.143644e+08  623208.461538    2925.615385
# std           1.249645e+07  202027.221753     611.660957
# min           2.873933e+08  265175.000000    1700.000000
# 25%           3.073077e+08  455541.500000    2563.250000
# 50%           3.161106e+08  693995.000000    2973.000000
# 75%           3.219079e+08  771908.500000    3215.000000
# max           3.376104e+08  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in sixtyfiveyears:
    sb.boxplot(data = sixtyfiveyears[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = sixtyfiveyears[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = sixtyfiveyears[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(sixtyfiveyears.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = sixtyfiveyears)

# %%
janssenvaccine=pd.DataFrame(vaccine['Administered_Janssen']) #extract the data for each vaccine type
modernavaccine=pd.DataFrame(vaccine['Administered_Moderna'])
pfizervaccine=pd.DataFrame(vaccine['Administered_Pfizer'])
novavaxvaccine=pd.DataFrame(vaccine['Administered_Novavax'])
janssenvaccine
# Out:
#     Administered_Janssen
# 0               38231027
# 1               38222094
# 2               38204327
# 3               38190149
# 4               38174475
# 5               38161040
# 6               38147982
# 7               38130397
# 8               38109603
# 9               38087745
# 10              38062212
# 11              38132505
# 12              38107592
# 13              38080888
# 14              38062240
# 15              38041703
# 16              38097694
# 17              38065302
# 18              38032273
# 19              38022222
# 20              37989944
# 21              37957052
# 22              37933793
# 23              37885266
# 24              37821060
# 25              37762561
# 26              37722104

# %%
janssenvaccine['Weekly Cases']=casesnumber #add weekly cases

# %%
janssenvaccine
# Out:
#     Administered_Janssen  Weekly Cases
# 0               38231027           NaN
# 1               38222094      265175.0
# 2               38204327      309887.0
# 3               38190149      342162.0
# 4               38174475      395071.0
# 5               38161040      471611.0
# 6               38147982      525650.0
# 7               38130397      616637.0
# 8               38109603      651675.0
# 9               38087745      694190.0
# 10              38062212      772447.0
# 11              38132505      839467.0
# 12              38107592      924235.0
# 13              38080888      905366.0
# 14              38062240      865597.0
# 15              38041703      779723.0
# 16              38097694      771796.0
# 17              38065302      693800.0
# 18              38032273      725592.0
# 19              38022222      771661.0
# 20              37989944      715689.0
# 21              37957052      771946.0
# 22              37933793      696358.0
# ...

# %%
janssenvaccine['Weekly Deaths']=deathnumber #add weekly deaths

# %%
janssenvaccine['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
janssenvaccine
# Out:
#     Administered_Janssen  Weekly Cases  Weekly Deaths  \
# 0               38231027           NaN            NaN
# 1               38222094      265175.0         2582.0
# 2               38204327      309887.0         2994.0
# 3               38190149      342162.0         2974.0
# 4               38174475      395071.0         3158.0
# 5               38161040      471611.0         3230.0
# 6               38147982      525650.0         2972.0
# 7               38130397      616637.0         4052.0
# 8               38109603      651675.0         3247.0
# 9               38087745      694190.0         3041.0
# 10              38062212      772447.0         3934.0
# 11              38132505      839467.0         3554.0
# 12              38107592      924235.0         3170.0
# 13              38080888      905366.0         2813.0
# 14              38062240      865597.0         3443.0
# 15              38041703      779723.0         1700.0
# ...

# %%
janssenvaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_Janssen                27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
janssenvaccine.describe()
# Out:
#        Administered_Janssen   Weekly Cases  Weekly Deaths  \
# count          2.700000e+01      26.000000      26.000000
# mean           3.805316e+07  623208.461538    2925.615385
# std            1.337219e+05  202027.221753     611.660957
# min            3.772210e+07  265175.000000    1700.000000
# 25%            3.800608e+07  455541.500000    2563.250000
# 50%            3.808089e+07  693995.000000    2973.000000
# 75%            3.814024e+07  771908.500000    3215.000000
# max            3.823103e+07  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in janssenvaccine:
    sb.boxplot(data = janssenvaccine[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = janssenvaccine[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = janssenvaccine[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(janssenvaccine.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = janssenvaccine)

# %%
modernavaccine['Weekly Cases']=casesnumber #add weekly cases

# %%
modernavaccine
# Out:
#     Administered_Moderna  Weekly Cases
# 0              478320828           NaN
# 1              475682213      265175.0
# 2              472658942      309887.0
# 3              470313002      342162.0
# 4              468109661      395071.0
# 5              466327117      471611.0
# 6              465887930      525650.0
# 7              465179986      616637.0
# 8              464279586      651675.0
# 9              463325081      694190.0
# 10             461901372      772447.0
# 11             461553903      839467.0
# 12             459871600      924235.0
# 13             458247889      905366.0
# 14             457090415      865597.0
# 15             456083999      779723.0
# 16             454616723      771796.0
# 17             453345061      693800.0
# 18             451725742      725592.0
# 19             450192843      771661.0
# 20             448324478      715689.0
# 21             446144226      771946.0
# 22             443758890      696358.0
# ...

# %%
modernavaccine['Weekly Deaths']=deathnumber #add weekly deaths

# %%
modernavaccine['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
modernavaccine
# Out:
#     Administered_Moderna  Weekly Cases  Weekly Deaths  \
# 0              478320828           NaN            NaN
# 1              475682213      265175.0         2582.0
# 2              472658942      309887.0         2994.0
# 3              470313002      342162.0         2974.0
# 4              468109661      395071.0         3158.0
# 5              466327117      471611.0         3230.0
# 6              465887930      525650.0         2972.0
# 7              465179986      616637.0         4052.0
# 8              464279586      651675.0         3247.0
# 9              463325081      694190.0         3041.0
# 10             461901372      772447.0         3934.0
# 11             461553903      839467.0         3554.0
# 12             459871600      924235.0         3170.0
# 13             458247889      905366.0         2813.0
# 14             457090415      865597.0         3443.0
# 15             456083999      779723.0         1700.0
# ...

# %%
modernavaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_Moderna                27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
modernavaccine.describe()
# Out:
#        Administered_Moderna   Weekly Cases  Weekly Deaths  \
# count          2.700000e+01      26.000000      26.000000
# mean           4.571072e+08  623208.461538    2925.615385
# std            1.208570e+07  202027.221753     611.660957
# min            4.328330e+08  265175.000000    1700.000000
# 25%            4.492587e+08  455541.500000    2563.250000
# 50%            4.582479e+08  693995.000000    2973.000000
# 75%            4.655340e+08  771908.500000    3215.000000
# max            4.783208e+08  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in modernavaccine:
    sb.boxplot(data = modernavaccine[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = modernavaccine[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = modernavaccine[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(modernavaccine.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = modernavaccine)

# %%
pfizervaccine['Weekly Cases']=casesnumber #add weekly cases

# %%
pfizervaccine
# Out:
#     Administered_Pfizer  Weekly Cases
# 0             753397231           NaN
# 1             748653618      265175.0
# 2             742769897      309887.0
# 3             737889828      342162.0
# 4             733311459      395071.0
# 5             730923017      471611.0
# 6             730012169      525650.0
# 7             728576494      616637.0
# 8             726779491      651675.0
# 9             724885217      694190.0
# 10            722443830      772447.0
# 11            721605001      839467.0
# 12            718880787      924235.0
# 13            716075417      905366.0
# 14            713934276      865597.0
# 15            712093007      779723.0
# 16            709124958      771796.0
# 17            706903774      693800.0
# 18            704275275      725592.0
# 19            701725317      771661.0
# 20            698787708      715689.0
# 21            695646394      771946.0
# 22            692573887      696358.0
# 23            689329602      588378.0
# ...

# %%
pfizervaccine['Weekly Deaths']=deathnumber #add weekly death

# %%
pfizervaccine['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
pfizervaccine
# Out:
#     Administered_Pfizer  Weekly Cases  Weekly Deaths  \
# 0             753397231           NaN            NaN
# 1             748653618      265175.0         2582.0
# 2             742769897      309887.0         2994.0
# 3             737889828      342162.0         2974.0
# 4             733311459      395071.0         3158.0
# 5             730923017      471611.0         3230.0
# 6             730012169      525650.0         2972.0
# 7             728576494      616637.0         4052.0
# 8             726779491      651675.0         3247.0
# 9             724885217      694190.0         3041.0
# 10            722443830      772447.0         3934.0
# 11            721605001      839467.0         3554.0
# 12            718880787      924235.0         3170.0
# 13            716075417      905366.0         2813.0
# 14            713934276      865597.0         3443.0
# 15            712093007      779723.0         1700.0
# 16            709124958      771796.0         2557.0
# ...

# %%
pfizervaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_Pfizer                 27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Deaths                       26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
pfizervaccine.describe()
# Out:
#        Administered_Pfizer   Weekly Cases  Weekly Deaths  \
# count         2.700000e+01      26.000000      26.000000
# mean          7.150329e+08  623208.461538    2925.615385
# std           2.037947e+07  202027.221753     611.660957
# min           6.778365e+08  265175.000000    1700.000000
# 25%           7.002565e+08  455541.500000    2563.250000
# 50%           7.160754e+08  693995.000000    2973.000000
# 75%           7.292943e+08  771908.500000    3215.000000
# max           7.533972e+08  924235.000000    4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in pfizervaccine:
    sb.boxplot(data = pfizervaccine[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = pfizervaccine[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = pfizervaccine[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(pfizervaccine.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = pfizervaccine)

# %%
novavaxvaccine['Weekly Cases']=casesnumber #add weekly cases

# %%
novavaxvaccine
# Out:
#     Administered_Novavax  Weekly Cases
# 0                  71559           NaN
# 1                  66850      265175.0
# 2                  61249      309887.0
# 3                  55203      342162.0
# 4                  48767      395071.0
# 5                  42025      471611.0
# 6                  36305      525650.0
# 7                  29445      616637.0
# 8                  24270      651675.0
# 9                  19769      694190.0
# 10                 14980      772447.0
# 11                 13510      839467.0
# 12                     0      924235.0
# 13                     0      905366.0
# 14                     0      865597.0
# 15                     0      779723.0
# 16                     0      771796.0
# 17                     0      693800.0
# 18                     0      725592.0
# 19                     0      771661.0
# 20                     0      715689.0
# 21                     0      771946.0
# 22                     0      696358.0
# ...

# %%
novavaxvaccine['Weekly Death']=deathnumber #add weekly death

# %%
novavaxvaccine['covid_hospital_admissions_per_100k']=hospitalisationcleaned #add hospital admissions

# %%
novavaxvaccine
# Out:
#     Administered_Novavax  Weekly Cases  Weekly Death  \
# 0                  71559           NaN           NaN
# 1                  66850      265175.0        2582.0
# 2                  61249      309887.0        2994.0
# 3                  55203      342162.0        2974.0
# 4                  48767      395071.0        3158.0
# 5                  42025      471611.0        3230.0
# 6                  36305      525650.0        2972.0
# 7                  29445      616637.0        4052.0
# 8                  24270      651675.0        3247.0
# 9                  19769      694190.0        3041.0
# 10                 14980      772447.0        3934.0
# 11                 13510      839467.0        3554.0
# 12                     0      924235.0        3170.0
# 13                     0      905366.0        2813.0
# 14                     0      865597.0        3443.0
# 15                     0      779723.0        1700.0
# 16                     0      771796.0        2557.0
# ...

# %%
novavaxvaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Administered_Novavax                27 non-null     int64
#  1   Weekly Cases                        26 non-null     float64
#  2   Weekly Death                        26 non-null     float64
#  3   covid_hospital_admissions_per_100k  27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 992.0 bytes

# %%
novavaxvaccine.describe()
# Out:
#        Administered_Novavax   Weekly Cases  Weekly Death  \
# count             27.000000      26.000000     26.000000
# mean           17923.407407  623208.461538   2925.615385
# std            24361.746908  202027.221753    611.660957
# min                0.000000  265175.000000   1700.000000
# 25%                0.000000  455541.500000   2563.250000
# 50%                0.000000  693995.000000   2973.000000
# 75%            32875.000000  771908.500000   3215.000000
# max            71559.000000  924235.000000   4154.000000
#
#        covid_hospital_admissions_per_100k
# count                           27.000000
# mean                         26154.674074
# std                          10640.689212
# min                           7788.200000
# 25%                          19550.450000
# 50%                          26494.800000
# 75%                          35619.700000
# max                          41707.300000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 3, figsize=(18, 24))

count = 0
for var in novavaxvaccine:
    sb.boxplot(data = novavaxvaccine[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = novavaxvaccine[var], kde=True, ax = axes[count,1])
    sb.violinplot(data = novavaxvaccine[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(novavaxvaccine.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Draw pairs of variables against one another
sb.pairplot(data = novavaxvaccine)

# %% [markdown]
# The magnitude of correlation between novavax and number of cases is the highest among the other pairs
#
# The correlation between novavax and number of cases is negative
#
# Therefore, more novavax helps to lower number of cases
#
# Thus, novavax is effective in combating the growth of Covid-19
